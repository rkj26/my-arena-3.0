# %%
import os
import random
import sys
from dataclasses import dataclass
from pathlib import Path
from typing import TypeAlias

import einops
import gymnasium as gym
import matplotlib.pyplot as plt
import numpy as np
import plotly.graph_objects as go
from tqdm import tqdm

Arr: TypeAlias = np.ndarray

max_episode_steps = 1000
N_RUNS = 200

# Make sure exercises are in the path
chapter = "chapter2_rl"
section = "part1_intro_to_rl"
# Find the root directory by checking if 'chapter' exists in the current directory or its parents
current_dir = Path.cwd()
if (current_dir / chapter).exists():
    root_dir = current_dir
else:
    root_dir = next(p for p in current_dir.parents if (p / chapter).exists())
exercises_dir = root_dir / chapter / "exercises"
section_dir = exercises_dir / section
if str(exercises_dir) not in sys.path:
    sys.path.append(str(exercises_dir))

import part1_intro_to_rl.tests as tests
import part1_intro_to_rl.utils as utils
from plotly_utils import cliffwalk_imshow, imshow, line
from part1_intro_to_rl.utils import GridWorld, Environment
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 32
#      28
#      29 import part1_intro_to_rl.tests as tests
#      30 import part1_intro_to_rl.utils as utils
#      31 from plotly_utils import cliffwalk_imshow, imshow, line
# ---> 32 from part1_intro_to_rl.utils import GridWorld, Environment
#
# ImportError: cannot import name 'GridWorld' from 'part1_intro_to_rl.utils' (/Users/rakshit/Documents/Github/my-arena-3.0/chapter2_rl/exercises/part1_intro_to_rl/utils.py)
